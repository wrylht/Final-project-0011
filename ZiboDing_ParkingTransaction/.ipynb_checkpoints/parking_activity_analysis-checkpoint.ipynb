# %% [markdown]
# # Individual Metric: Parking Activity as a Measure of Neighborhood Vibrancy
#
# ## Introduction
#
# For my individual part of the final project, I define the “best” neighborhood as the most vibrant and frequently visited area. In my view, a good neighborhood is a place where people want to go for restaurants, shopping, entertainment, work, and other activities.
#
# To measure this idea, I use the Aggregated Parking Transactions dataset from the Pittsburgh Parking Authority. Parking transactions can act as a proxy for neighborhood activity. If a parking zone has many transactions, it suggests that many people are choosing to visit that area. Therefore, I treat higher parking activity as evidence that a neighborhood or local area is more popular and active.
#
# In this analysis, I treat parking zones as representations of local areas within the city.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the Dataset
#
# The dataset contains parking transaction information aggregated by parking zone and time of day. Each row includes a parking zone, a time interval, meter transactions, mobile transactions, and payment information.

# %%
df = pd.read_csv("aggregated-transactions-2019-09-03.csv")
df.head()
df.columns
df.shape
# Out:
# (4481746, 9)

# %% [markdown]
# ## Cleaning and Preparing the Data
#
# The dataset separates transactions into meter transactions and mobile transactions. Since both represent people paying for parking, I combine them into one total transaction count. This total transaction count is the main variable used in my metric.

# %%
df["total_transactions"] = df["meter_transactions"] + df["mobile_transactions"]
df[["zone", "meter_transactions", "mobile_transactions", "total_transactions"]].head()
df["start"] = pd.to_datetime(df["start"])
df["hour"] = df["start"].dt.hour
df["date"] = df["start"].dt.date
df.head()
# Out:
#     _id                             zone               start  \
# 0  5037  335 - Friendship Cedarville Lot 2014-01-04 11:40:00
# 1  5038          341 - 18th & Sidney Lot 2014-01-04 11:40:00
# 2  5039            342 - East Carson Lot 2014-01-04 11:40:00
# 3  5040          343 - 19th & Carson Lot 2014-01-04 11:40:00
# 4  5041          344 - 18th & Carson Lot 2014-01-04 11:40:00
#
#                    end            utc_start  meter_transactions  \
# 0  2014-01-04T11:50:00  2014-01-04T16:40:00                   2
# 1  2014-01-04T11:50:00  2014-01-04T16:40:00                   2
# 2  2014-01-04T11:50:00  2014-01-04T16:40:00                   1
# 3  2014-01-04T11:50:00  2014-01-04T16:40:00                   2
# 4  2014-01-04T11:50:00  2014-01-04T16:40:00                   7
#
#    meter_payments  mobile_transactions  mobile_payments  total_transactions  \
# 0            1.00                    0              0.0                   2
# ...

# %% [markdown]
# ## Metric
#
# My metric is based on total parking transactions.
#
# A higher number of total parking transactions means that more people parked in that area. Under my definition of “best,” this suggests that the area is more vibrant, popular, and frequently visited.
#
# The formula is: `total_transactions = meter_transactions + mobile_transactions`

# %%
zone_activity = df.groupby("zone")["total_transactions"].sum().reset_index()

zone_activity = zone_activity.sort_values(
    by="total_transactions",
    ascending=False
).reset_index(drop=True)

zone_activity.index = zone_activity.index + 1

zone_activity
# Out:
#                                zone  total_transactions
# 1                    415 - SS & SSW             4628490
# 2             404 - Strip Disctrict             3103130
# 3               413 - Squirrel Hill             3050698
# 4      406 - Bloomfield (On-street)             2395129
# 5                   421 - NorthSide             2356951
# 6                   411 - Shadyside             2331267
# 7                   410 - Oakland 4             2321233
# 8                  402 - Downtown 2             2170131
# 9                  401 - Downtown 1             2132738
# 10               412 - East Liberty             2002645
# 11                  409 - Oakland 3             1959210
# 12                  408 - Oakland 2             1884701
# 13                  407 - Oakland 1             1633854
# 14                     403 - Uptown             1561626
# 15         328 - Ivy Bellefonte Lot             1048258
# 16                  419 - Brookline              882050
# ...

# %% [markdown]
# ## Top Parking Zones
#
# The table below shows the top 10 parking zones by total parking transactions. These are the areas with the highest parking activity in the dataset.

# %%
top10 = zone_activity.head(10)
top10

plt.figure(figsize=(12, 6))
plt.bar(top10["zone"], top10["total_transactions"])
plt.title("Top 10 Most Active Parking Areas in Pittsburgh")
plt.xlabel("Parking Area")
plt.ylabel("Total Parking Transactions")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# This visualization shows that a small number of parking areas account for a large portion of parking activity. This suggests that activity in Pittsburgh is concentrated in specific high-demand areas.

# %% [markdown]
# ## Normalized Parking Activity Score
#
# To make the results easier to compare, I create a normalized activity score. The busiest parking zone receives a score of 1.0, and all other zones are scored relative to it.

# %%
zone_activity["activity_score"] = zone_activity["total_transactions"] / zone_activity["total_transactions"].max()

zone_activity
# Out:
#                                zone  total_transactions  activity_score
# 1                    415 - SS & SSW             4628490        1.000000
# 2             404 - Strip Disctrict             3103130        0.670441
# 3               413 - Squirrel Hill             3050698        0.659113
# 4      406 - Bloomfield (On-street)             2395129        0.517475
# 5                   421 - NorthSide             2356951        0.509227
# 6                   411 - Shadyside             2331267        0.503678
# 7                   410 - Oakland 4             2321233        0.501510
# 8                  402 - Downtown 2             2170131        0.468864
# 9                  401 - Downtown 1             2132738        0.460785
# 10               412 - East Liberty             2002645        0.432678
# 11                  409 - Oakland 3             1959210        0.423294
# 12                  408 - Oakland 2             1884701        0.407196
# ...

# %%
top10_score = zone_activity.head(10)

plt.figure(figsize=(12, 6))
plt.bar(top10_score["zone"], top10_score["activity_score"])
plt.title("Top 10 Parking Areas by Normalized Activity Score")
plt.xlabel("Parking Area")
plt.ylabel("Activity Score")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# The normalized score makes the ranking easier to interpret. The top area receives a score of 1.0, while the other areas are compared against that top area.

# %% [markdown]
# ### Mapping Parking Zones to Neighborhoods
#
# To align this analysis with neighborhood-level metrics used by other group members, I map each parking zone to its corresponding official Pittsburgh neighborhoods.
#
# Since the original data is aggregated at the parking zone level, each neighborhood within a zone is assigned the same normalized activity score. This allows for consistent comparison across different datasets while preserving the structure of the original data.
#
# This step enables integration of parking activity with other neighborhood-based metrics in the final group analysis.

# %%
zone_to_neighborhood = {
    "415 - SS & SSW": "South Side Flats / South Side Slopes",
    "404 - Strip Disctrict": "Strip District",
    "413 - Squirrel Hill": "Squirrel Hill North / Squirrel Hill South",
    "406 - Bloomfield (On-street)": "Bloomfield",
    "421 - NorthSide": "North Shore / Allegheny Center / Central Northside / East Allegheny / Allegheny West",
    "411 - Shadyside": "Shadyside",
    "410 - Oakland 4": "North Oakland / Central Oakland / South Oakland / West Oakland",
    "402 - Downtown 2": "Central Business District",
    "401 - Downtown 1": "Central Business District",
    "412 - East Liberty": "East Liberty",
    "409 - Oakland 3": "North Oakland / Central Oakland / South Oakland / West Oakland",
    "408 - Oakland 2": "North Oakland / Central Oakland / South Oakland / West Oakland",
    "407 - Oakland 1": "North Oakland / Central Oakland / South Oakland / West Oakland",
    "403 - Uptown": "Uptown",
    "328 - Ivy Bellefonte Lot": "Shadyside",
    "419 - Brookline": "Brookline",
    "405 - Lawrenceville": "Lower Lawrenceville / Central Lawrenceville / Upper Lawrenceville",
    "422 - Northshore": "North Shore",
    "322 - Forbes Shady Lot": "Squirrel Hill North / Squirrel Hill South",
    "324 - Forbes Murray Lot": "Squirrel Hill North / Squirrel Hill South",
    "325 - JCC/Forbes Lot": "Squirrel Hill North / Squirrel Hill South",
    "344 - 18th & Carson Lot": "South Side Flats",
    "321 - Beacon Bartlett Lot": "Squirrel Hill North / Squirrel Hill South",
    "335 - Friendship Cedarville Lot": "Friendship",
    "341 - 18th & Sidney Lot": "South Side Flats",
    "357 - Shiloh Street Lot": "Mount Washington",
    "342 - East Carson Lot": "South Side Flats",
    "304 - Tamello Beatty Lot": "East Liberty",
    "420 - Mt. Washington": "Mount Washington",
    "302 - Sheridan Kirkwood Lot": "East Liberty",
    "343 - 19th & Carson Lot": "South Side Flats",
    "338 - 42nd & Butler Lot": "Central Lawrenceville",
    "345 - 20th & Sidney Lot": "South Side Flats",
    "371 - East Ohio Street Lot": "East Allegheny",
    "323 - Douglas Phillips Lot": "Squirrel Hill North / Squirrel Hill South",
    "334 - Taylor Street Lot": "Bloomfield",
    "307 - Eva Beatty Lot": "East Liberty",
    "416 - Carrick": "Carrick",
    "414 - Mellon Park": "Point Breeze / Shadyside / Squirrel Hill North",
    "418 - Beechview": "Beechview",
    "329 - Centre Craig": "North Oakland",
    "351 - Brownsville & Sandkey Lot": "Carrick",
    "424 - Technology Drive": "South Oakland",
    "314 - Penn Circle NW Lot": "East Liberty",
    "425 - Bakery Sq": "Larimer / Shadyside",
    "301 - Sheridan Harvard Lot": "East Liberty",
    "337 - 52nd & Butler Lot": "Upper Lawrenceville",
    "355 - Asteroid Warrington Lot": "Allentown",
    "311 - Ansley Beatty Lot": "East Liberty",
    "423 - West End": "West End",
    "417 - Allentown": "Allentown",
    "369 - Main/Alexander Lot": "Bloomfield",
    "308 - Harvard Beatty Lot": "East Liberty",
    "375 - Oberservatory Hill Lot": "Perry North / Observatory Hill",
    "426 - Hill District": "Bedford Dwellings / Middle Hill / Crawford-Roberts / Terrace Village / Upper Hill",
    "363 - Beechview Lot": "Beechview",
    "427 - Knoxville": "Knoxville",
    "354 - Walter/Warrington Lot": "Allentown",
    "361 - Brookline Lot": "Brookline",
    "331 - Homewood Zenith Lot": "Homewood North / Homewood South / Homewood West"
}

zone_neighborhood_score = zone_activity.copy()
zone_neighborhood_score["neighborhood"] = zone_neighborhood_score["zone"].map(zone_to_neighborhood)

zone_neighborhood_score = zone_neighborhood_score[
    ["zone", "neighborhood", "total_transactions", "activity_score"]
]

zone_neighborhood_score
# Out:
#                                zone  \
# 1                    415 - SS & SSW
# 2             404 - Strip Disctrict
# 3               413 - Squirrel Hill
# 4      406 - Bloomfield (On-street)
# 5                   421 - NorthSide
# 6                   411 - Shadyside
# 7                   410 - Oakland 4
# 8                  402 - Downtown 2
# 9                  401 - Downtown 1
# 10               412 - East Liberty
# 11                  409 - Oakland 3
# 12                  408 - Oakland 2
# 13                  407 - Oakland 1
# 14                     403 - Uptown
# 15         328 - Ivy Bellefonte Lot
# 16                  419 - Brookline
# 17              405 - Lawrenceville
# 18                 422 - Northshore
# 19           322 - Forbes Shady Lot
# 20          324 - Forbes Murray Lot
# 21             325 - JCC/Forbes Lot
# 22          344 - 18th & Carson Lot
# 23        321 - Beacon Bartlett Lot
# 24  335 - Friendship Cedarville Lot
# 25          341 - 18th & Sidney Lot
# ...

# %%
rows = []

for _, row in zone_activity.iterrows():
    zone = row["zone"]
    score = row["activity_score"]
    
    neighborhoods = zone_to_neighborhood.get(zone, "")
    
    for n in neighborhoods.split(" / "):
        rows.append({
            "neighborhood": n.strip(),
            "activity_score": score
        })

neighborhood_df = pd.DataFrame(rows)

neighborhood_df = (
    neighborhood_df
    .groupby("neighborhood")["activity_score"]
    .max()
    .reset_index()
)

neighborhood_df = neighborhood_df.sort_values(
    by="activity_score",
    ascending=False
).reset_index(drop=True)

neighborhood_df.index += 1

neighborhood_df
# Out:
#                  neighborhood  activity_score
# 1           South Side Slopes        1.000000
# 2            South Side Flats        1.000000
# 3              Strip District        0.670441
# 4         Squirrel Hill South        0.659113
# 5         Squirrel Hill North        0.659113
# 6                  Bloomfield        0.517475
# 7            Allegheny Center        0.509227
# 8              Allegheny West        0.509227
# 9           Central Northside        0.509227
# 10                North Shore        0.509227
# 11             East Allegheny        0.509227
# 12                  Shadyside        0.503678
# 13              South Oakland        0.501510
# 14              North Oakland        0.501510
# 15               West Oakland        0.501510
# 16            Central Oakland        0.501510
# 17  Central Business District        0.468864
# 18               East Liberty        0.432678
# 19                     Uptown        0.337394
# ...

# %%
top10_neighborhood_score = neighborhood_df.head(10)

plt.figure(figsize=(12, 6))

plt.bar(top10_neighborhood_score["neighborhood"], top10_neighborhood_score["activity_score"])

plt.title("Top 10 Neighborhoods by Parking Activity Score")
plt.xlabel("Neighborhood")
plt.ylabel("Activity Score")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Result
#
# Based on the aggregated parking transaction data, the most active parking area is **415 - SS & SSW**, which has the highest number of total parking transactions in the dataset (4,628,490). This parking zone corresponds to the South Side area, specifically **South Side Flats** and **South Side Slopes**.

# %%
best_zone = zone_activity.iloc[0]

neighborhoods = zone_to_neighborhood.get(best_zone["zone"], "")

print("Best area based on parking activity:")
print(best_zone["zone"])
print("Corresponding neighborhoods:", neighborhoods)
print("Total transactions:", best_zone["total_transactions"])
print("Activity score:", best_zone["activity_score"])
# Out:
# Best area based on parking activity:
# 415 - SS & SSW
# Corresponding neighborhoods: South Side Flats / South Side Slopes
# Total transactions: 4628490
# Activity score: 1.0

# %% [markdown]
# ## Conclusion
#
# In this analysis, I defined the “best” neighborhood as the most vibrant and frequently visited area, using parking transactions as a proxy for activity.
#
# Based on the results, the area **415 - SS & SSW (South Side and SouthSide Works)** has the highest parking activity in the dataset. This parking zone broadly corresponds to Pittsburgh’s South Side area, which is officially divided into **South Side Flats** and **South Side Slopes**, with SouthSide Works serving as a major commercial and entertainment center within this region. This suggests that these areas are among the most popular and frequently visited locations in Pittsburgh.
#
# This finding aligns well with real-world characteristics of the area. South Side, especially along East Carson Street, is known for its dense concentration of restaurants and bars. In addition, SouthSide Works serves as a major shopping and entertainment center, attracting visitors throughout the day. These factors contribute to consistently high levels of parking demand.
#
# Therefore, the data-driven result is supported by real-world evidence: areas with more amenities and attractions tend to draw more visitors, leading to higher parking activity. Under my definition of “best,” this makes **South Side Flats** and **South Side Slopes** the strongest candidates for the best neighborhoods under this metric.
#
# However, my personal preference may be different from this data-driven result. Personally, I would probably prefer a neighborhood based more on safety and residential comfort. This means that even though **South Side Flats** and **South Side Slopes** rank highest under my parking-activity metric, another neighborhood could be my personal favorite if I focused on safety, quietness, or livability instead.
